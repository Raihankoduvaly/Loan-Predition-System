# %% [markdown]
# ## <CENTER>**LOAN APPROVAL PREDITION SYSTEM USING ML**</CENTER>

# %% [markdown]
# ### **INDRODUCTION**

# %% [markdown]
# #### <span style="color:darkblue">In today's fast-paced financial world, banks and lending institutions face the constant challenge of making quick, accurate decisions about loan approvals. Traditionally, this process relied heavily on manual assessments, which were often time-consuming, subjective, and prone to human error. </span>
#
# #### <span style="color:darkblue">To streamline this process, we introduce a Loan Approval Prediction System powered by Machine Learning. By analyzing historical loan data and learning patterns from factors like income, employment status, credit history, and loan amount, our system can predict whether a loan application is likely to be approved or denied.<span>
#
# #### <span style="color:darkblue">This not only helps lenders make faster, more informed decisions but also creates a fairer and more transparent process for applicants. With machine learning, we move towards smarter, data-driven lending — minimizing risk, increasing efficiency, and building trust in the system.</span>

# %% [markdown]
# ### **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### 	**Train Set**

# %%
df=pd.read_csv('train.csv')

# %% [markdown]
# ### **Data Preprocessing**

# %%
df.head()
# Out:
#    id  person_age  person_income person_home_ownership  person_emp_length  \
# 0   0          37          35000                  RENT                0.0
# 1   1          22          56000                   OWN                6.0
# 2   2          29          28800                   OWN                8.0
# 3   3          30          70000                  RENT               14.0
# 4   4          22          60000                  RENT                2.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_percent_income  \
# 0   EDUCATION          B       6000          11.49                 0.17
# 1     MEDICAL          C       4000          13.35                 0.07
# 2    PERSONAL          A       6000           8.90                 0.21
# 3     VENTURE          B      12000          11.11                 0.17
# 4     MEDICAL          A       6000           6.92                 0.10
#
#   cb_person_default_on_file  cb_person_cred_hist_length  loan_status
# 0                         N                          14            0
# 1                         N                           2            0
# 2                         N                          10            0
# 3                         N                           5            0
# 4                         N                           3            0

# %% [markdown]
# ### Showing the shape of the dataset

# %%
df.shape
# Out:
# (58645, 13)

# %% [markdown]
# ### 	Removing unwanted columns

# %%
df.drop('id', axis=1, inplace=True)

# %% [markdown]
# ### Showing the shape of the dataset after removing the 'id' column.

# %%
df.shape
# Out:
# (58645, 12)

# %% [markdown]
# ### Showing the information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  58645 non-null  int64
#  1   person_income               58645 non-null  int64
#  2   person_home_ownership       58645 non-null  object
#  3   person_emp_length           58645 non-null  float64
#  4   loan_intent                 58645 non-null  object
#  5   loan_grade                  58645 non-null  object
#  6   loan_amnt                   58645 non-null  int64
#  7   loan_int_rate               58645 non-null  float64
#  8   loan_percent_income         58645 non-null  float64
#  9   cb_person_default_on_file   58645 non-null  object
#  10  cb_person_cred_hist_length  58645 non-null  int64
#  11  loan_status                 58645 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 5.4+ MB

# %% [markdown]
# ### Showing the null values of the dataset

# %%
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# loan_status                   0
# dtype: int64

# %%
#Showing the duplicated values of the dataset
df.duplicated().sum()
# Out:
# 0

# %%
#showing the extra statistical measures of the dataset
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  58645.000000   5.864500e+04       58645.000000  58645.000000
# mean      27.550857   6.404617e+04           4.701015   9217.556518
# std        6.033216   3.793111e+04           3.959784   5563.807384
# min       20.000000   4.200000e+03           0.000000    500.000000
# 25%       23.000000   4.200000e+04           2.000000   5000.000000
# 50%       26.000000   5.800000e+04           4.000000   8000.000000
# 75%       30.000000   7.560000e+04           7.000000  12000.000000
# max      123.000000   1.900000e+06         123.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   58645.000000         58645.000000                58645.000000
# mean       10.677874             0.159238                    5.813556
# std         3.034697             0.091692                    4.029196
# min         5.420000             0.000000                    2.000000
# 25%         7.880000             0.090000                    3.000000
# 50%        10.750000             0.140000                    4.000000
# 75%        12.990000             0.210000                    8.000000
# max        23.220000             0.830000                   30.000000
#
#         loan_status
# count  58645.000000
# mean       0.142382
# std        0.349445
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ### Showing the extra statistical measures of the dataset including categorical columns also

# %%
df.describe(include='all')
# Out:
#           person_age  person_income person_home_ownership  person_emp_length  \
# count   58645.000000   5.864500e+04                 58645       58645.000000
# unique           NaN            NaN                     4                NaN
# top              NaN            NaN                  RENT                NaN
# freq             NaN            NaN                 30594                NaN
# mean       27.550857   6.404617e+04                   NaN           4.701015
# std         6.033216   3.793111e+04                   NaN           3.959784
# min        20.000000   4.200000e+03                   NaN           0.000000
# 25%        23.000000   4.200000e+04                   NaN           2.000000
# 50%        26.000000   5.800000e+04                   NaN           4.000000
# 75%        30.000000   7.560000e+04                   NaN           7.000000
# max       123.000000   1.900000e+06                   NaN         123.000000
#
#        loan_intent loan_grade     loan_amnt  loan_int_rate  \
# count        58645      58645  58645.000000   58645.000000
# unique           6          7           NaN            NaN
# top      EDUCATION          A           NaN            NaN
# freq         12271      20984           NaN            NaN
# mean           NaN        NaN   9217.556518      10.677874
# std            NaN        NaN   5563.807384       3.034697
# min            NaN        NaN    500.000000       5.420000
# 25%            NaN        NaN   5000.000000       7.880000
# 50%            NaN        NaN   8000.000000      10.750000
# 75%            NaN        NaN  12000.000000      12.990000
# max            NaN        NaN  35000.000000      23.220000
#
#         loan_percent_income cb_person_default_on_file  \
# count          58645.000000                     58645
# unique                  NaN                         2
# top                     NaN                         N
# freq                    NaN                     49943
# mean               0.159238                       NaN
# std                0.091692                       NaN
# min                0.000000                       NaN
# 25%                0.090000                       NaN
# 50%                0.140000                       NaN
# 75%                0.210000                       NaN
# max                0.830000                       NaN
#
#         cb_person_cred_hist_length   loan_status
# count                 58645.000000  58645.000000
# unique                         NaN           NaN
# top                            NaN           NaN
# freq                           NaN           NaN
# mean                      5.813556      0.142382
# std                       4.029196      0.349445
# min                       2.000000      0.000000
# 25%                       3.000000      0.000000
# 50%                       4.000000      0.000000
# 75%                       8.000000      0.000000
# max                      30.000000      1.000000

# %% [markdown]
# ### Showing the unique values of the dataset

# %%
df.nunique()
# Out:
# person_age                      53
# person_income                 2641
# person_home_ownership            4
# person_emp_length               36
# loan_intent                      6
# loan_grade                       7
# loan_amnt                      545
# loan_int_rate                  362
# loan_percent_income             61
# cb_person_default_on_file        2
# cb_person_cred_hist_length      29
# loan_status                      2
# dtype: int64

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### 1) Distribution of the dataset

# %%
df.hist(figsize=(15,13))

plt.show()

# %% [markdown]
# ### 2) Shwoing the Labeled column of the dataset

# %%
sn.countplot(x='loan_status', data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %% [markdown]
# ### 3) Showing the Numerical columns and then performing analysis

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns

num_cols
# Out:
# Index(['person_age', 'person_income', 'person_emp_length', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'loan_status'],
#       dtype='object')

# %%
	#i) Visualizing the Numerical columns using Distribution plot and Box plot
for col in num_cols:
    f, ax=plt.subplots(1,2, figsize=(18, 5.5))
    
    # Distribution plot
    sn.histplot(x=col, data=df, kde=True, color='deepskyblue', ax=ax[0])
    ax[0].set_title(f'{col}')
    
    # Boxplot
    sn.boxplot(x=col, data=df, ax=ax[1])
    
    plt.show()

# %% [markdown]
# ### 4) Showing the Categorical columns and then performing analysis

# %%
cat_cols=df.select_dtypes(include=['object']).columns

cat_cols
# Out:
# Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')

# %% [markdown]
# ### Checking unique columns of the Categorical values

# %%
for col in cat_cols:
    result=df[col].value_counts()
    print(result)
    print("===========================")
# Out:
# person_home_ownership
# RENT        30594
# MORTGAGE    24824
# OWN          3138
# OTHER          89
# Name: count, dtype: int64
# ===========================
# loan_intent
# EDUCATION            12271
# MEDICAL              10934
# PERSONAL             10016
# VENTURE              10011
# DEBTCONSOLIDATION     9133
# HOMEIMPROVEMENT       6280
# Name: count, dtype: int64
# ===========================
# loan_grade
# A    20984
# B    20400
# C    11036
# D     5034
# E     1009
# F      149
# G       33
# Name: count, dtype: int64
# ===========================
# cb_person_default_on_file
# N    49943
# Y     8702
# Name: count, dtype: int64
# ===========================

# %% [markdown]
# ### ii) Visualizing the Categorical columns using Countplot and Pie Chart

# %%
for col in cat_cols:
    
    f, ax=plt.subplots(1,2, figsize=(18,5.5))
    
    # Count plot
    sn.countplot(x=col, data=df, ax=ax[0])
    ax[0].set_title(f'{col}')
    
    # Pie chart
    df[col].value_counts().plot(kind='pie', autopct='%.1f%%', shadow=True, ax=ax[1])
    
    plt.show()

# %% [markdown]
# ### 5) Showing the Numerical columns with Respect to Labeled Column

# %%
for col in num_cols:
    sn.histplot(x=col, data=df, kde=True, hue='loan_status')
    plt.show()

# %% [markdown]
# ### 6) Showing the Categorical columns with Respect to Labeled Column

# %%
for col in cat_cols:
    sn.countplot(x=col, data=df, hue='loan_status')
    plt.xticks(rotation=45)
    plt.show()

# %% [markdown]
# ### 	7) Label Encoding for Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
#	Before label Encoding
for col in cat_cols:
    result=df[col].value_counts()
    print(result)
    print("===========================")
# Out:
# person_home_ownership
# RENT        30594
# MORTGAGE    24824
# OWN          3138
# OTHER          89
# Name: count, dtype: int64
# ===========================
# loan_intent
# EDUCATION            12271
# MEDICAL              10934
# PERSONAL             10016
# VENTURE              10011
# DEBTCONSOLIDATION     9133
# HOMEIMPROVEMENT       6280
# Name: count, dtype: int64
# ===========================
# loan_grade
# A    20984
# B    20400
# C    11036
# D     5034
# E     1009
# F      149
# G       33
# Name: count, dtype: int64
# ===========================
# cb_person_default_on_file
# N    49943
# Y     8702
# Name: count, dtype: int64
# ===========================

# %%
#After Label Encoding
for col in cat_cols:
    df[col]=lb.fit_transform(df[col])

# %%
for col in cat_cols:
    result=df[col].value_counts()
    print(result)
    print("===========================")
# Out:
# person_home_ownership
# 3    30594
# 0    24824
# 2     3138
# 1       89
# Name: count, dtype: int64
# ===========================
# loan_intent
# 1    12271
# 3    10934
# 4    10016
# 5    10011
# 0     9133
# 2     6280
# Name: count, dtype: int64
# ===========================
# loan_grade
# 0    20984
# 1    20400
# 2    11036
# 3     5034
# 4     1009
# 5      149
# 6       33
# Name: count, dtype: int64
# ===========================
# cb_person_default_on_file
# 0    49943
# 1     8702
# Name: count, dtype: int64
# ===========================

# %% [markdown]
# ### 8) Visualizing the Correlation using Heatmap

# %%
plt.figure(figsize=(12,6))

sn.heatmap(df.corr(), fmt='.2f', annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
#
# ### 9) Visualizing the Correlation with Respect to Labeled Column

# %%
df.corr()['loan_status'].sort_values(ascending=False).plot(kind='bar', figsize=(20,6))
# Out:
# <Axes: >

# %% [markdown]
# ### Train Test Split

# %%
X=df.drop('loan_status',axis=1)
Y=df['loan_status']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X, Y, test_size=0.2, random_state=101)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (58645, 11) (46916, 11) (11729, 11)

# %% [markdown]
# ### **Scaling**

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.56949361, -0.91682987,  0.22268896, ...,  0.00503159,
#         -0.41648216,  1.03462243],
#        [-0.09171287,  0.4191634 , -1.15472372, ..., -0.75751252,
#         -0.41648216, -0.20300763],
#        [-1.0835226 ,  0.15822722,  0.91139529, ..., -1.08431714,
#         -0.41648216, -0.69805965],
#        ...,
#        [-0.42231612,  0.02775912, -1.15472372, ..., -0.97538227,
#         -0.41648216, -0.94558566],
#        [-1.0835226 , -0.12880259,  0.91139529, ...,  2.18372904,
#         -0.41648216, -0.69805965],
#        [ 2.71841468,  0.02775912, -1.15472372, ..., -0.10390329,
#         -0.41648216,  2.27225248]])

# %% [markdown]
# ### **Model Training**

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\user\anaconda3\lib\site-packages (from xgboost) (1.13.1)
# Downloading xgboost-3.0.0-py3-none-win_amd64.whl (150.0 MB)
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/150.0 MB 4.2 MB/s eta 0:00:36
#    ---------------------------------------- 1.3/150.0 MB 4.2 MB/s eta 0:00:36
#     --------------------------------------- 2.6/150.0 MB 4.7 MB/s eta 0:00:32
#    - -------------------------------------- 3.9/150.0 MB 5.5 MB/s eta 0:00:27
#    - -------------------------------------- 6.3/150.0 MB 6.5 MB/s eta 0:00:22
#    -- ------------------------------------- 8.1/150.0 MB 7.0 MB/s eta 0:00:21
#    -- ------------------------------------- 10.5/150.0 MB 7.5 MB/s eta 0:00:19
#    --- ------------------------------------ 13.9/150.0 MB 8.7 MB/s eta 0:00:16
#    ---- ----------------------------------- 18.4/150.0 MB 10.2 MB/s eta 0:00:13
#    ------ --------------------------------- 23.6/150.0 MB 11.9 MB/s eta 0:00:11
#    ------- -------------------------------- 28.3/150.0 MB 12.9 MB/s eta 0:00:10
#    -------- ------------------------------- 33.6/150.0 MB 14.3 MB/s eta 0:00:09
#    ---------- ----------------------------- 40.1/150.0 MB 15.4 MB/s eta 0:00:08
#    ------------ --------------------------- 46.1/150.0 MB 16.4 MB/s eta 0:00:07
#    ------------- -------------------------- 51.4/150.0 MB 17.5 MB/s eta 0:00:06
#    --------------- ------------------------ 58.7/150.0 MB 18.3 MB/s eta 0:00:05
#    ----------------- ---------------------- 64.2/150.0 MB 18.8 MB/s eta 0:00:05
#    ------------------ --------------------- 69.7/150.0 MB 19.2 MB/s eta 0:00:05
#    ------------------- -------------------- 73.1/150.0 MB 19.1 MB/s eta 0:00:05
#    --------------------- ------------------ 81.3/150.0 MB 20.1 MB/s eta 0:00:04
#    ----------------------- ----------------
xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score

# %%
def metrices_info(model):
    y_pred=model.predict(X_test)
    
    acc=accuracy_score(Y_test, y_pred)
    conf=confusion_matrix(Y_test, y_pred)
    cff=classification_report(Y_test, y_pred)
    
    y1_pred=model.predict(X_train)
    train_acc=accuracy_score(Y_train, y1_pred)
    
    print('Train Accuracy: ', train_acc)
    print('Test Accuracy: ', acc)
    print("==================================")
    
    print('Confusion Matrix: ')
    print(conf)
    print("=========================================")
    print('Classification Report: ')
    print(cff)
    print("======================================================")

# %% [markdown]
# ### **i) Logistic Regression**

# %%
Lr=LogisticRegression(max_iter=1000)

Lr.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
#a) Metrices Information
metrices_info(Lr)
# Out:
# Train Accuracy:  0.8954514451359877
# Test Accuracy:  0.8989683689999147
# ==================================
# Confusion Matrix:
# [[9872  253]
#  [ 932  672]]
# =========================================
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94     10125
#            1       0.73      0.42      0.53      1604
#
#     accuracy                           0.90     11729
#    macro avg       0.82      0.70      0.74     11729
# weighted avg       0.89      0.90      0.89     11729
#
# ======================================================

# %% [markdown]
# ### b) ROC Curve

# %%
y_pred=Lr.predict_proba(X_test)[:,-1]
roc_curve=roc_auc_score(Y_test, y_pred)

roc_curve
# Out:
# 0.8833096887411102

# %% [markdown]
# ### **ADDBOOSTER**

# %%
ad=AdaBoostClassifier()
ad.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier()

# %%
#Metrices Information	
metrices_info(ad)
# Out:
# Train Accuracy:  0.9271037599113309
# Test Accuracy:  0.9294910052007844
# ==================================
# Confusion Matrix:
# [[9891  234]
#  [ 593 1011]]
# =========================================
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96     10125
#            1       0.81      0.63      0.71      1604
#
#     accuracy                           0.93     11729
#    macro avg       0.88      0.80      0.83     11729
# weighted avg       0.93      0.93      0.93     11729
#
# ======================================================

# %%
#b) ROC Curve
y_pred=ad.predict_proba(X_test)[:,-1]
roc_curve=roc_auc_score(Y_test, y_pred)

roc_curve
# Out:
# 0.921243958006219

# %%
#c) Feature Importances
y_pred=ad.predict(X_test)

perform=pd.DataFrame({'Col': X.columns, 'Feature Importances':ad.feature_importances_})


sn.barplot(y='Col', x='Feature Importances', data=perform)

plt.show()

# %% [markdown]
# ### v) LGBM

# %%
lgm=LGBMClassifier()

lgm.fit(X_train,Y_train)
# Out:
# [LightGBM] [Info] Number of positive: 6746, number of negative: 40170
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000772 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 890
# [LightGBM] [Info] Number of data points in the train set: 46916, number of used features: 11
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143789 -> initscore=-1.784171
# [LightGBM] [Info] Start training from score -1.784171
# LGBMClassifier()

# %%
#a) Metrices Information
metrices_info(lgm)
# Out:
# Train Accuracy:  0.9562409412567141
# Test Accuracy:  0.955239150822747
# ==================================
# Confusion Matrix:
# [[10044    81]
#  [  444  1160]]
# =========================================
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97     10125
#            1       0.93      0.72      0.82      1604
#
#     accuracy                           0.96     11729
#    macro avg       0.95      0.86      0.89     11729
# weighted avg       0.95      0.96      0.95     11729
#
# ======================================================

# %%
#b) ROC Curve
y_pred=lgm.predict_proba(X_test)[:,-1]
roc_curve=roc_auc_score(Y_test, y_pred)

roc_curve
# Out:
# 0.9595544780025246

# %%
#c) Feature Importances
y_pred=ad.predict(X_test)

perform=pd.DataFrame({'Col': X.columns, 'Feature Importances':lgm.feature_importances_})


sn.barplot(y='Col', x='Feature Importances', data=perform)

plt.show()

# %% [markdown]
# ### vi) CatBoost

# %%
ct=CatBoostClassifier()

ct.fit(X_train,Y_train)
# Out:
# 703:	learn: 0.1280592	total: 10.1s	remaining: 4.26s
# 704:	learn: 0.1280341	total: 10.1s	remaining: 4.25s
# 705:	learn: 0.1280020	total: 10.2s	remaining: 4.23s
# 706:	learn: 0.1279734	total: 10.2s	remaining: 4.21s
# 707:	learn: 0.1279458	total: 10.2s	remaining: 4.2s
# 708:	learn: 0.1279244	total: 10.2s	remaining: 4.18s
# 709:	learn: 0.1278873	total: 10.2s	remaining: 4.17s
# 710:	learn: 0.1278538	total: 10.2s	remaining: 4.15s
# 711:	learn: 0.1278122	total: 10.2s	remaining: 4.14s
# 712:	learn: 0.1277745	total: 10.2s	remaining: 4.12s
# 713:	learn: 0.1277303	total: 10.3s	remaining: 4.11s
# 714:	learn: 0.1276819	total: 10.3s	remaining: 4.09s
# 715:	learn: 0.1276487	total: 10.3s	remaining: 4.08s
# 716:	learn: 0.1275806	total: 10.3s	remaining: 4.06s
# 717:	learn: 0.1275513	total: 10.3s	remaining: 4.04s
# 718:	learn: 0.1275098	total: 10.3s	remaining: 4.03s
# 719:	learn: 0.1274433	total: 10.3s	remaining: 4.02s
# 720:	learn: 0.1274065	total: 10.3s	remaining: 4s
# 721:	learn: 0.1273725	total: 10.4s	remaining: 3.98s
# 722:	learn: 0.1273536	total: 10.4s	remaining: 3.97s
# 723:	learn: 0.1273429	total: 10.4s	remaining: 3.96s
# 724:	learn: 0.1273169	total: 10.4s	remaining: 3.94s
# 725:	learn: 0.1272808	total: 10.4s	remaining: 3.92s
# 726:	learn: 0.1272334	total: 10.4s	remaining: 3.91s
# 727:	learn: 0.1271714	total: 10.4s	remaining: 3.9s
# 728:	learn: 0.1271323	total: 10.4s	remaining: 3.88s
# 729:	learn: 0.1271119	total: 10.4s	remaining: 3.86s
# 730:	learn: 0.1270666	total: 10.5s	remaining: 3.85s
# 731:	learn: 0.1270197	total: 10.5s	remaining: 3.83s
# 732:	learn: 0.1269881	total: 10.5s	remaining: 3.82s
# 733:	learn: 0.1269410	total: 10.5s	remaining: 3.8s
# 734:	learn: 0.1269181	total: 10.5s	remaining: 3.79s
# 735:	learn: 0.1268894	total: 10.5s	remaining: 3.77s
# 736:	learn: 0.1268320	total: 10.5s	remaining: 3.76s
# 737:	learn: 0.1267978	total: 10.5s	remaining: 3.74s
# 738:	learn: 0.1267588	total: 10.6s	remaining: 3.73s
# 739:	learn: 0.1267198	total: 10.6s	remaining: 3.71s
# 740:	learn: 0.1267015	total: 10.6s	remaining: 3.7s
# 741:	learn: 0.1266738	total: 10.6s	remaining: 3.68s
# 742:	learn: 0.1266461	total: 10.6s	remaining: 3.67s
# 743:	learn: 0.1266070	total: 10.6s	remaining: 3.65s
# 744:	learn: 0.1265752	total: 10.6s	remaining: 3.63s
# 745:	learn: 0.1265364	total: 10.6s	remaining: 3.62s
# 746:	learn: 0.1264887	total: 10.6s	remaining: 3.6s
# 747:	learn: 0.1264574	total: 10.7s	remaining: 3.59s
# 748:	learn: 0.1264276	total: 10.7s	remaining: 3.57s
# 749:	learn: 0.1263925	total: 10.7s	remaining: 3.56s
# 891:	learn: 0.1216079	total: 12.3s	remaining: 1.49s
# 892:	learn: 0.1215750	total: 12.3s	remaining: 1.47s
# 893:	learn: 0.1215292	total: 12.3s	remaining: 1.46s
# 894:	learn: 0.1214924	total: 12.3s	remaining: 1.45s
# 895:	learn: 0.1214537	total: 12.3s	remaining: 1.43s
# 896:	learn: 0.1214319	total: 12.3s	remaining: 1.42s
# 897:	learn: 0.1214104	total: 12.4s	remaining: 1.4s
# 898:	learn: 0.1213601	total: 12.4s	remaining: 1.39s
# 899:	learn: 0.1213236	total: 12.4s	remaining: 1.38s
# 900:	learn: 0.1212896	total: 12.4s	remaining: 1.36s
# 901:	learn: 0.1212269	total: 12.4s	remaining: 1.35s
# 902:	learn: 0.1211902	total: 12.4s	remaining: 1.34s
# 903:	learn: 0.1211639	total: 12.5s	remaining: 1.32s
# 904:	learn: 0.1211253	total: 12.5s	remaining: 1.31s
# 905:	learn: 0.1210667	total: 12.5s	remaining: 1.29s
# 906:	learn: 0.1210241	total: 12.5s	remaining: 1.28s
# 907:	learn: 0.1209724	total: 12.5s	remaining: 1.27s
# 908:	learn: 0.1209360	total: 12.5s	remaining: 1.25s
# 909:	learn: 0.1209037	total: 12.5s	remaining: 1.24s
# 910:	learn: 0.1208780	total: 12.6s	remaining: 1.23s
# 911:	learn: 0.1208303	total: 12.6s	remaining: 1.21s
# 912:	learn: 0.1207935	total: 12.6s	remaining: 1.2s
# 913:	learn: 0.1207831	total: 12.6s	remaining: 1.18s
# 914:	learn: 0.1207537	total: 12.6s	remaining: 1.17s
# 915:	learn: 0.1207115	total: 12.6s	remaining: 1.16s
# 916:	learn: 0.1206733	total: 12.6s	remaining: 1.14s
# 917:	learn: 0.1206469	total: 12.7s	remaining: 1.13s
# 918:	learn: 0.1206256	total: 12.7s	remaining: 1.12s
# 919:	learn: 0.1206037	total: 12.7s	remaining: 1.1s
# 920:	learn: 0.1205654	total: 12.7s	remaining: 1.09s
# 921:	learn: 0.1205289	total: 12.7s	remaining: 1.07s
# 922:	learn: 0.1205121	total: 12.7s	remaining: 1.06s
# 923:	learn: 0.1204869	total: 12.7s	remaining: 1.05s
# 924:	learn: 0.1204646	total: 12.7s	remaining: 1.03s
# 925:	learn: 0.1204405	total: 12.8s	remaining: 1.02s
# 926:	learn: 0.1204212	total: 12.8s	remaining: 1s
# 927:	learn: 0.1203987	total: 12.8s	remaining: 991ms
# 928:	learn: 0.1203619	total: 12.8s	remaining: 977ms
# 929:	learn: 0.1203223	total: 12.8s	remaining: 963ms
# 930:	learn: 0.1202977	total: 12.8s	remaining: 949ms
# 931:	learn: 0.1202676	total: 12.8s	remaining: 936ms
# 932:	learn: 0.1202232	total: 12.8s	remaining: 922ms
# 933:	learn: 0.1201940	total: 12.8s	remaining: 908ms
# 934:	learn: 0.1201758	total: 12.9s	remaining: 894ms
# 935:	learn: 0.1201176	total: 12.9s	remaining: 880ms
# 936:	learn: 0.1200790	total: 12.9s	remaining: 866ms
# 937:	learn: 0.1200480	total: 12.9s	remaining: 853ms
# 986:	learn: 0.1184828	total: 13.6s	remaining: 179ms
# 987:	learn: 0.1184528	total: 13.6s	remaining: 165ms
# 988:	learn: 0.1184283	total: 13.6s	remaining: 151ms
# 989:	learn: 0.1183865	total: 13.6s	remaining: 137ms
# 990:	learn: 0.1183817	total: 13.6s	remaining: 124ms
# 991:	learn: 0.1183626	total: 13.6s	remaining: 110ms
# 992:	learn: 0.1183162	total: 13.6s	remaining: 96.1ms
# 993:	learn: 0.1182786	total: 13.6s	remaining: 82.3ms
# 994:	learn: 0.1182576	total: 13.7s	remaining: 68.6ms
# 995:	learn: 0.1182154	total: 13.7s	remaining: 54.9ms
# 996:	learn: 0.1181927	total: 13.7s	remaining: 41.2ms
# 997:	learn: 0.1181514	total: 13.7s	remaining: 27.5ms
# 998:	learn: 0.1181244	total: 13.7s	remaining: 13.7ms
# 999:	learn: 0.1181080	total: 13.7s	remaining: 0us

# %%
#a) Metrices Information
metrices_info(ct)
# Out:
# Train Accuracy:  0.9606530821041862
# Test Accuracy:  0.9560917384261233
# ==================================
# Confusion Matrix:
# [[10043    82]
#  [  433  1171]]
# =========================================
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98     10125
#            1       0.93      0.73      0.82      1604
#
#     accuracy                           0.96     11729
#    macro avg       0.95      0.86      0.90     11729
# weighted avg       0.96      0.96      0.95     11729
#
# ======================================================

# %%
#b) ROC Curve
y_pred=ct.predict_proba(X_test)[:,-1]
roc_curve=roc_auc_score(Y_test, y_pred)

roc_curve
# Out:
# 0.9581071395585111

# %%
#c) Feature Importances
y_pred=ad.predict(X_test)

perform=pd.DataFrame({'Col': X.columns, 'Feature Importances':ct.feature_importances_})


sn.barplot(y='Col', x='Feature Importances', data=perform)

plt.show()

# %% [markdown]
# #### Above this we can come into this conclusion that, our model is CatBoost

# %% [markdown]
# ### **Test Set**

# %%
test_df=pd.read_csv('test.csv')

# %%
test_df.head()
# Out:
#       id  person_age  person_income person_home_ownership  person_emp_length  \
# 0  58645          23          69000                  RENT                3.0
# 1  58646          26          96000              MORTGAGE                6.0
# 2  58647          26          30000                  RENT                5.0
# 3  58648          33          50000                  RENT                4.0
# 4  58649          26         102000              MORTGAGE                8.0
#
#          loan_intent loan_grade  loan_amnt  loan_int_rate  \
# 0    HOMEIMPROVEMENT          F      25000          15.76
# 1           PERSONAL          C      10000          12.68
# 2            VENTURE          E       4000          17.19
# 3  DEBTCONSOLIDATION          A       7000           8.90
# 4    HOMEIMPROVEMENT          D      15000          16.32
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.36                         N                           2
# 1                 0.10                         Y                           4
# 2                 0.13                         Y                           2
# 3                 0.14                         N                           7
# 4                 0.15                         Y                           4

# %%
test_df_copy=test_df.copy()

# %%
test_df.shape
# Out:
# (39098, 12)

# %%
test_df.drop('id', axis=1, inplace=True)

# %%
test_df.shape
# Out:
# (39098, 11)

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39098 entries, 0 to 39097
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  39098 non-null  int64
#  1   person_income               39098 non-null  int64
#  2   person_home_ownership       39098 non-null  object
#  3   person_emp_length           39098 non-null  float64
#  4   loan_intent                 39098 non-null  object
#  5   loan_grade                  39098 non-null  object
#  6   loan_amnt                   39098 non-null  int64
#  7   loan_int_rate               39098 non-null  float64
#  8   loan_percent_income         39098 non-null  float64
#  9   cb_person_default_on_file   39098 non-null  object
#  10  cb_person_cred_hist_length  39098 non-null  int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 3.3+ MB

# %% [markdown]
# ### Checking the null values in test set

# %%
test_df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
#checking the duplicates
test_df.duplicated().sum()
# Out:
# 0

# %%
#Label Encoding for Categorical Columns
test_cat=test_df.select_dtypes(include=['object']).columns

test_cat
# Out:
# Index(['person_home_ownership', 'loan_intent', 'loan_grade',
#        'cb_person_default_on_file'],
#       dtype='object')

# %%
#before label encoding
for col in test_cat:
    result=test_df[col].value_counts()
    print(result)
    print("===========================")
# Out:
# person_home_ownership
# RENT        20280
# MORTGAGE    16683
# OWN          2056
# OTHER          79
# Name: count, dtype: int64
# ===========================
# loan_intent
# EDUCATION            8076
# MEDICAL              7447
# PERSONAL             6815
# VENTURE              6632
# DEBTCONSOLIDATION    5915
# HOMEIMPROVEMENT      4213
# Name: count, dtype: int64
# ===========================
# loan_grade
# A    14005
# B    13604
# C     7460
# D     3269
# E      637
# F      105
# G       18
# Name: count, dtype: int64
# ===========================
# cb_person_default_on_file
# N    33227
# Y     5871
# Name: count, dtype: int64
# ===========================

# %%
for col in test_cat:
    test_df[col]=lb.fit_transform(test_df[col])

# %%
#after label encoding
for col in test_cat:
    result=test_df[col].value_counts()
    print(result)
    print("===========================")
# Out:
# person_home_ownership
# 3    20280
# 0    16683
# 2     2056
# 1       79
# Name: count, dtype: int64
# ===========================
# loan_intent
# 1    8076
# 3    7447
# 4    6815
# 5    6632
# 0    5915
# 2    4213
# Name: count, dtype: int64
# ===========================
# loan_grade
# 0    14005
# 1    13604
# 2     7460
# 3     3269
# 4      637
# 5      105
# 6       18
# Name: count, dtype: int64
# ===========================
# cb_person_default_on_file
# 0    33227
# 1     5871
# Name: count, dtype: int64
# ===========================

# %% [markdown]
# ### **Scaling the dataset**

# %%
test_df=sc.transform(test_df)

# %% [markdown]
# ### **Prediction**

# %%
y_pred=ct.predict(test_df)

# %%
y_pred_ct=ct.predict_proba(test_df)[:,1]

# %%
sub=pd.DataFrame({'id': test_df_copy['id'], 'loan_status':y_pred_ct})

# %%
sub
# Out:
#           id  loan_status
# 0      58645     0.999150
# 1      58646     0.018012
# 2      58647     0.396653
# 3      58648     0.012627
# 4      58649     0.083241
# ...      ...          ...
# 39093  97738     0.036551
# 39094  97739     0.004105
# 39095  97740     0.006594
# 39096  97741     0.102568
# 39097  97742     0.959962
#
# [39098 rows x 2 columns]

# %%
sub.to_csv('sample_submission', index=False)

# %% [markdown]
# ### **Saving the Model**

# %%
import pickle

# %%
pickle.dump(ct, open('CatBoost.pkl', 'wb'))
pickle.dump(sc, open('Scaler.pkl', 'wb'))
pickle.dump(lb, open('LabelEncoder.pkl', 'wb'))

# %% [markdown]
# ### **Prediction**

# %%
X.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_default_on_file',
#        'cb_person_cred_hist_length'],
#       dtype='object')

# %%
def prediction_results(person_age, person_income, person_home_ownership,person_emp_length, loan_intent, loan_grade, 
                       loan_amnt,loan_int_rate, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length,
                      sc,ct):
    
    features=np.array([[person_age, person_income, person_home_ownership,person_emp_length, loan_intent, loan_grade, 
                       loan_amnt,loan_int_rate, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]])
    
    scaled_features=sc.transform(features)
    
    result=ct.predict(scaled_features)
    
    return result

# %% [markdown]
# ## **a) Test Case 1**

# %%
person_age=27
person_income=50000 
person_home_ownership=3
person_emp_length= 1.0
loan_intent=3
loan_grade=2
loan_amnt=12000
loan_int_rate= 13.49
loan_percent_income=0.24 
cb_person_default_on_file=0 
cb_person_cred_hist_length=6

result=prediction_results(person_age, person_income, person_home_ownership,person_emp_length, loan_intent, loan_grade, 
                          loan_amnt,loan_int_rate, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length,
                         sc,ct)

if result==0:
    print("Loan Approval Rejected")
else:
    print("Loan Approval Accepted")
# Out:
# Loan Approval Rejected

# %% [markdown]
# ## **b) Test Case 2**

# %%
person_age=33
person_income=30000 
person_home_ownership=3
person_emp_length= 2.0
loan_intent=1
loan_grade=1
loan_amnt=15000
loan_int_rate= 10.99
loan_percent_income=0.5
cb_person_default_on_file=0 
cb_person_cred_hist_length=7

result=prediction_results(person_age, person_income, person_home_ownership,person_emp_length, loan_intent, loan_grade, 
                          loan_amnt,loan_int_rate, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length,
                         sc,ct)

if result==0:
    print("Loan Approval Rejected")
else:
    print("Loan Approval Accepted")
# Out:
# Loan Approval Accepted

# %% [markdown]
# ### **PREDICTION MODEL**

# %%
print("Please enter the following details:")

Gender = input("Gender (Male/Female): ")
Married = input("Married (Yes/No): ")
Dependents = input("Number of Dependents (0, 1, 2, 3+): ")
Education = input("Education (Graduate/Not Graduate): ")
Self_Employed = input("Self Employed (Yes/No): ")
ApplicantIncome = float(input("Applicant Income: "))
CoapplicantIncome = float(input("Coapplicant Income: "))
LoanAmount = float(input("Loan Amount (in thousands): "))
Loan_Amount_Term = float(input("Loan Amount Term (in days): "))
Credit_History = float(input("Credit History (1.0/0.0): "))
Property_Area = input("Property Area (Urban/Rural/Semiurban): ")

# Put the inputs into a dataframe
import pandas as pd

input_data = pd.DataFrame({
    'Gender': [Gender],
    'Married': [Married],
    'Dependents': [Dependents],
    'Education': [Education],
    'Self_Employed': [Self_Employed],
    'ApplicantIncome': [ApplicantIncome],
    'CoapplicantIncome': [CoapplicantIncome],
    'LoanAmount': [LoanAmount],
    'Loan_Amount_Term': [Loan_Amount_Term],
    'Credit_History': [Credit_History],
    'Property_Area': [Property_Area]
})

# NOTE: You need to apply the same preprocessing steps you used for training!

# For example, if you used LabelEncoder:
# input_data['Gender'] = gender_encoder.transform(input_data['Gender'])
# (And similarly for others.)

# Predict
prediction = model.predict(input_data)

# Output
if prediction[0] == 1:
    print("Loan Approved ✅")
else:
    print("Loan Not Approved ❌")
# Out:
# Please enter the following details:
# Gender (Male/Female):  male
# Married (Yes/No):  yes
